# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/gdrive')

train = pd.read_csv('/content/gdrive/MyDrive/open/train.csv')
test = pd.read_csv('/content/gdrive/MyDrive/open/test.csv')
sub = pd.read_csv('/content/gdrive/MyDrive/open/sample_submission.csv')
snp_info = pd.read_csv('/content/gdrive/MyDrive/open/snp_info.csv')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
train.head()
# Out:
#           id  father  mother  gender  trait SNP_01 SNP_02 SNP_03 SNP_04  \
# 0  TRAIN_000       0       0       0      2    G G    A G    A A    G A
# 1  TRAIN_001       0       0       0      2    A G    A G    C A    A A
# 2  TRAIN_002       0       0       0      2    G G    G G    A A    G A
# 3  TRAIN_003       0       0       0      1    A A    G G    A A    G A
# 4  TRAIN_004       0       0       0      2    G G    G G    C C    A A
#
#   SNP_05  ... SNP_07 SNP_08 SNP_09 SNP_10 SNP_11 SNP_12 SNP_13 SNP_14 SNP_15  \
# 0    C A  ...    A A    G G    A A    G G    A G    A A    A A    A A    A A
# 1    A A  ...    A A    G A    A A    A G    A A    G A    G G    A A    A A
# 2    C C  ...    A A    G A    G A    A G    A A    A A    A A    A A    A A
# 3    A A  ...    G G    A A    G G    A G    G G    G G    G G    A A    G G
# 4    C C  ...    A A    A A    A A    G G    A A    A A    A G    A A    G A
#
#   class
# 0     B
# 1     C
# 2     B
# 3     A
# 4     C
#
# ...

# %%
test.head()
# Out:
#          id  father  mother  gender  trait SNP_01 SNP_02 SNP_03 SNP_04 SNP_05  \
# 0  TEST_000       0       0       0      1    A G    G G    A A    G A    A A
# 1  TEST_001       0       0       0      2    G G    A G    C C    G G    C C
# 2  TEST_002       0       0       0      2    G G    A G    A A    A A    C A
# 3  TEST_003       0       0       0      2    G G    A G    C A    A A    C C
# 4  TEST_004       0       0       0      1    A A    G G    A A    G G    A A
#
#   SNP_06 SNP_07 SNP_08 SNP_09 SNP_10 SNP_11 SNP_12 SNP_13 SNP_14 SNP_15
# 0    A G    G G    G A    G A    A G    A G    G A    G G    C A    G A
# 1    A A    A A    A A    A A    G G    A G    A A    A A    A A    A A
# 2    A G    A A    A A    A A    A G    A A    G A    G G    A A    G G
# 3    A A    A A    A A    A A    G G    A A    G A    A G    A A    A A
# 4    G G    G G    A A    G G    A G    G G    G A    G G    A A    G G

# %%
df_list = [train,test]

# %%
for df in df_list:
    print(df.isna().sum())
# Out:
# id        0
# father    0
# mother    0
# gender    0
# trait     0
# SNP_01    0
# SNP_02    0
# SNP_03    0
# SNP_04    0
# SNP_05    0
# SNP_06    0
# SNP_07    0
# SNP_08    0
# SNP_09    0
# SNP_10    0
# SNP_11    0
# SNP_12    0
# SNP_13    0
# SNP_14    0
# SNP_15    0
# class     0
# dtype: int64
# id        0
# father    0
# mother    0
# gender    0
# trait     0
# SNP_01    0
# SNP_02    0
# SNP_03    0
# SNP_04    0
# SNP_05    0
# SNP_06    0
# SNP_07    0
# SNP_08    0
# SNP_09    0
# SNP_10    0
# SNP_11    0
# SNP_12    0
# SNP_13    0
# SNP_14    0
# SNP_15    0
# dtype: int64

# %%
dic = {"A A":0,"C C":1,"G G":2,"A C":3,"C A":4,"A G":5,"G A":6}
snp_list = ["SNP_01","SNP_02","SNP_03","SNP_04","SNP_05","SNP_06","SNP_07","SNP_08","SNP_09","SNP_10","SNP_11","SNP_12","SNP_13","SNP_14","SNP_15"]
for snp in snp_list:
    for df in df_list:
        df[snp] = df[snp].map(dic)

# %%
train.head()
# Out:
#           id  father  mother  gender  trait  SNP_01  SNP_02  SNP_03  SNP_04  \
# 0  TRAIN_000       0       0       0      2       2       5       0       6
# 1  TRAIN_001       0       0       0      2       5       5       4       0
# 2  TRAIN_002       0       0       0      2       2       2       0       6
# 3  TRAIN_003       0       0       0      1       0       2       0       6
# 4  TRAIN_004       0       0       0      2       2       2       1       0
#
#    SNP_05  ...  SNP_07  SNP_08  SNP_09  SNP_10  SNP_11  SNP_12  SNP_13  \
# 0       4  ...       0       2       0       2       5       0       0
# 1       0  ...       0       6       0       5       0       6       2
# 2       1  ...       0       6       6       5       0       0       0
# 3       0  ...       2       0       2       5       2       2       2
# 4       1  ...       0       0       0       2       0       0       5
#
#    SNP_14  SNP_15  class
# 0       0       0      B
# 1       0       0      C
# ...

# %%
train = train.drop(columns=["id","father","mother","gender"])
test = test.drop(columns=["id","father","mother","gender"])

# %%
X_train = train.drop(columns=["class"])
y_train = train["class"]
X_test = test
